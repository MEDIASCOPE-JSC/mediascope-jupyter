# %% [markdown]
# # Загрузка всех доступных данных

# %% [markdown]
# Пример загрузки архива с csv-файлами

# %% [markdown]
# ## Описание задачи
# - Период: весь доступный период
# - Метод: download
# - Тип файлов: активность, словарь брендов, словарь категорий, словарь соц.-дем параметров

# %% [markdown]
# ### Инициализация

# %% [markdown]
# Импортируем библиотеки, которые понадобятся для работы.\
# Выполните следующую ячейку, для этого перейдите в нее и нажмите Shift + Enter

# %%
import pandas as pd
import numpy as np

from fileapiback import *

# %% [markdown]
# ### Формирование задания

# %% [markdown]
# Зададим условия\
# *см. подробнее формат условий в блокноте [help.ipynb](help.ipynb)*

# %%
# укажите тип файла в формате: 'brand_dict', 'cat_dict', 'activity', 'socdem_dict'
filetype = 'activity'

# дополнительно укажите период, если тип файла 'activity' или 'socdem_dict'
# формат периода: ['ГГГГ-ММ-01'] (ОДИН конкретный месяц) или None (все месяцы)
period = None

# %% [markdown]
# ### Выполнение задания
# Скачивание файлов в виде архива

# %%
obj = FileApi()

# формируем задание для FileAPI
result = obj.File_Api_Mediascope(method='download', filetype=filetype, period=period)

print(f'В директорию загружен архив {result}')

# %% [markdown]
# ---

# %% [markdown]
# С примерами расчетов показателей можно ознакомиться в ноутбуках:
# - [FileApi_calculation_categories.ipynb](FileApi_calculation_categories.ipynb)
# - [FileApi_calculation_brands.ipynb](FileApi_calculation_brands.ipynb)
# - [FileApi_calculation_brands_SoS.ipynb](FileApi_calculation_brands_SoS.ipynb)
# - [FileApi_calculation_demography.ipynb](FileApi_calculation_demography.ipynb)
# - [FileApi_calculation_demography_SoS.ipynb](FileApi_calculation_demography_SoS.ipynb)
