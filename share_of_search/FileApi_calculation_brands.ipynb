# %% [markdown]
# # Бренды: основные показатели

# %% [markdown]
# Пример расчета базовых показателей по брендам и категориям

# %% [markdown]
# ## Описание задачи и условий расчета
# - Период: весь доступный период
# - Категории: все доступные категории (в примере "Смартфоны")
# - Бренды: бренды доступных категорий
# - Статистики: количество запросов (тыс), распределение запросов по типу ресурса (%)

# %% [markdown]
# ### Инициализация

# %% [markdown]
# Импортируем библиотеки, которые понадобятся для работы.\
# Выполните следующую ячейку, для этого перейдите в нее и нажмите Shift + Enter

# %%
import pandas as pd
import numpy as np

from fileapiback import *

# %% [markdown]
# ### Формирование задания

# %% [markdown]
# Зададим условия для расчета.\
# *см. подробнее формат условий в блокноте [help.ipynb](help.ipynb)*

# %%
# укажите период в формате:
# None (все месяцы с активностью в архиве) или ['YYYY-MM-01', 'YYYY-MM-01'] (конкретные месяцы)
period = None

# укажите одну категорию брендов для фильтрации в формате: 'Категория'
category_filter = 'Смартфоны'

# укажите бренды из категории для фильтрации в формате:
# None (все бренды) или  ['бренд1', 'бренд2']
brand_filter = None

# укажите, нужна ли разбивка ecom для показателя "Распределение запросов по типу ресурса": 
# да - True, нет - False
flag_filter = False

# %% [markdown]
# ### Выполнение задания
# - Визуализация динамики количества запросов
# - Расчет
#   - количества запросов в разбивке по брендам по месяцам (млн)
#   - распределения запросов в разбивке по брендам по типу ресурса по месяцам (%)

# %%
# формирование pandas.DataFrame

obj = FileApi()

# создаем pandas.DataFrame
data = obj.create_pdDF(note='brand', period=period, category_filter=category_filter, 
                       brand_filter=brand_filter, flag_filter=flag_filter)

# %%
# расчет количества запросов в разбивке по категориям по брендам по месяцам

qcnt = (data
        .groupby(['month', 'Category', 'Brand'])['Weight'] # группируем по месяцу, категории, бренду и считаем количество запросов
        .sum()  # сумма по группе
        .reset_index(name='QCnt000')  # переименование столбца
        .sort_values(by=['month', 'Category', 'QCnt000'], ascending=[True, True, False])  # сортировка
    )
# округляем показатели
qcnt['QCnt000'] = (qcnt['QCnt000'] / 1000)

# %%
# построение графика

obj.draw_diagram(df=qcnt, period=period, col='QCnt000', brand_cat='Brand')

# %%
# распределение запросов в разбивке по категориям по брендам по типу ресурса

# считаем количество запросов
res_share = (data
             .groupby(['month', 'Category', 'Brand', 'ResourceType'])['Weight'] #группируем по месяцу, категории, типу ресерса
             .sum()
             .reset_index(name='QCnt')
            )

res_share['QCnt_all'] = res_share.groupby(['month', 'Category', 'Brand'])['QCnt'].transform('sum') # добавляем общую сумму
res_share['%'] = (res_share['QCnt'] / res_share['QCnt_all'] * 100).round(1) # вычисляем процент

# выбираем нужные столбцы и сортируем
res_share = (res_share[['month', 'Category', 'Brand', 'ResourceType', '%']]
            .sort_values(['month', 'Category', 'Brand', '%'], ascending=[True, True, True, False]))

# %% [markdown]
# ## Экспорт в Excel
# По умолчанию файл 'brands-metrics-YYYYMMDD_HHMMSS.xlsx' сохраняется в ту же директорию, где лежат все блокноты

# %%
time_now = datetime.now().strftime('%Y%m%d_%H%M%S')

with pd.ExcelWriter(f'brands-metrics-{time_now}.xlsx') as writer:
    qcnt.to_excel(writer, 'qcnt', index=False)
    res_share.to_excel(writer, 'res_share', index=False)
