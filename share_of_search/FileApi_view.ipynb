# %% [markdown]
# # Просмотр доступных файлов с данными

# %% [markdown]
# Пример просмотра списка доступных файлов и даты их последнего обновления.

# %% [markdown]
# ## Описание задачи
# - Период: весь доступный период
# - Метод: list
# - Тип файлов: активность, словарь брендов, словарь категорий, словарь соц.-дем параметров

# %% [markdown]
# ### Инициализация

# %% [markdown]
# Импортируем библиотеки, которые понадобятся для работы.\
# Выполните следующую ячейку, для этого перейдите в нее и нажмите Shift + Enter

# %%
import pandas as pd
import numpy as np

from fileapiback import *

# %% [markdown]
# ### Формирование задания

# %% [markdown]
# Зададим условия\
# *см. подробнее формат условий в блокноте [help.ipynb](help.ipynb)*

# %%
# укажите тип файла: 'brand_dict', 'cat_dict', 'activity', 'socdem_dict'
filetype = 'socdem_dict'

# дополнительно укажите нужный месяц для типа файла 'activity', 'socdem_dict'
# форматы периода: ['ГГГГ-ММ-01'] (ОДИН конкретный месяц) или None (все месяцы)
period = None

# %% [markdown]
# ### Выполнение задания
# Просмотр списка доступных файлов:

# %%
obj = FileApi()
print("Результат:")

# формируем задание для FileAPI
result_list = obj.File_Api_Mediascope(method='list', filetype=filetype, period=period)
